# %% [markdown]
# ![](https://i.imgur.com/KhDDHls.gif)
# ![](https://i.imgur.com/Ffjv44w.gif)

# %% [markdown]
# <div style="color: White; display: fill;
#             border-radius: 5px;
#             background-color: #123456;
#             font-size: 100%;
#             font-family: Verdana">
#
# <p style="padding: 7px; color: Black;">
#       <ul>  📌 <b>Customer ID</b> - Unique identifier for each customer.<br>
#         📌 <b>Age</b> - Age of the customer.<br>
#         📌 <b>Gender</b> - Gender of the customer (Male/Female).<br>
#         📌 <b>Item Purchased</b> - The item purchased by the customer.<br>
#         📌 <b>Category</b> - Category of the item purchased.<br>
#         📌 <b>Purchase Amount (USD)</b> - The amount of the purchase in USD.<br>
#         📌 <b>Location</b> - Location where the purchase was made.<br>
#         📌 <b>Size</b> - Size of the purchased item.<br>
#         📌 <b>Color</b> - Color of the purchased item.<br>
#         📌 <b>Season</b> - Season during which the purchase was made.<br>
#         📌 <b>Review Rating</b> - Rating given by the customer for the purchased item.<br>
#         📌 <b>Subscription Status</b> - Indicates if the customer has a subscription (Yes/No).<br>
#         📌 <b>Shipping Type</b> - Type of shipping chosen by the customer.<br>
#         📌 <b>Discount Applied</b> - Indicates if a discount was applied to the purchase (Yes/No).<br>
#         📌 <b>Promo Code Used</b> - Indicates if a promo code was used for the purchase (Yes/No).<br>
#         📌 <b>Previous Purchases</b> - Number of previous purchases made by the customer.<br>
#         📌 <b>Payment Method</b> - Customer's most preferred payment method.<br>
#         📌 <b>Frequency of Purchases</b> - Frequency at which the customer makes purchases (e.g., Weekly, Fortnightly, Monthly).<br><br>
#     <p style = "padding: 3px; color: Black;">

# %%
# !pip install WordCloud

# %%
import numpy as np 
import pandas as pd  
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.express as px

# %% [markdown]
# # Above Libraries are imported
#
# ---
#
# ## **1. NumPy**
# - NumPy is a core library for numerical and scientific computing in Python.
# - **Features**:
#   - Supports multi-dimensional arrays and matrices.
#   - Provides functions for numerical computations like linear algebra, statistics, and random sampling.
#
# ### **Usage in this Project**:
# - Performing mathematical operations and handling array-based data.
#
# ## **2. Pandas**
# - Pandas is a powerful data analysis and manipulation library.
# - **Features**:
#   - Provides data structures like DataFrames and Series.
#   - Allows reading, cleaning, and transforming datasets easily.
# ### **Usage in this Project**:
#   - Loading, transforming, and analyzing datasets.
#
# ### **3. Seaborn**
#    - Seaborn is a Python data visualization library based on Matplotlib.
#    - **Features**:
#       - Provides beautiful and informative statistical graphics.
#       - Useful for visualizing distributions, relationships, and trends in data.
# ### **Usage in this Project**:
#        - Creating statistical plots like histograms, box plots, and scatter plots.
#
# ### **4. Matplotlib**
#      - Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations.
#      - **Features**:
#         - Highly customizable for creating various types of plots.
#         - Works as the foundation for other visualization libraries like Seaborn.
# ### **Usage in this Project**:
#         - Creating simple plots to visualize data trends.
# ### **5. Plotly Express**
#      - Plotly Express is a high-level Python library for creating interactive visualizations.
#     - **Features**:
#       - Quick and easy to use for dynamic plots.
#        - Supports a variety of visualizations, such as scatter plots, bar charts, and maps.
# ### **Usage in this Project**:
#        - Creating interactive plots to enhance data exploration.

# %% [markdown]
# ### Code Explanation
#
# The following line of code is used to read the `shopping_trends_updated.csv` file and load its contents into a pandas DataFrame:

# %%
shop = pd.read_csv(r'C:\Users\ADMIN\Desktop\AICTE\shopping_trends_updated.csv')

# %% [markdown]
# ## Purpose of shop.shape
#     - Returns the dimensions of the DataFrame as a tuple.

# %%
shop.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# ## Purpose of shop.dtypes
#        - Displays the data type of each column in the DataFrame.

# %%
shop.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %% [markdown]
# ## Purpose of shop.columns
#        - This command lists all the column names present in the DataFrame

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# Purpose of shop.info()
#        - Provides a concise summary of the DataFrame.

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
shop.shape
# Out:
# (3900, 19)

# %% [markdown]
# ## Purpose shop.isnull().sum()
#      - Counts the number of missing (null) values in each column.

# %%
shop.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# Age_category              0
# dtype: int64

# %%
print(f"The unique values of the 'Gender' column are: {shop['Gender'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Category' column are: {shop['Category'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Size' column are: {shop['Size'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Subscription Status' column are: {shop['Subscription Status'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Shipping Type' column are: {shop['Shipping Type'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Discount Applied' column are: {shop['Discount Applied'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Promo Code Used' column are: {shop['Promo Code Used'].unique()}")
print()# This will print a blank line
print(f"The unique values of the 'Payment Method' column are: {shop['Payment Method'].unique()}")
# Out:
# The unique values of the 'Gender' column are: ['Male' 'Female']
#
# The unique values of the 'Category' column are: ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
#
# The unique values of the 'Size' column are: ['L' 'S' 'M' 'XL']
#
# The unique values of the 'Subscription Status' column are: ['Yes' 'No']
#
# The unique values of the 'Shipping Type' column are: ['Express' 'Free Shipping' 'Next Day Air' 'Standard' '2-Day Shipping'
#  'Store Pickup']
#
# The unique values of the 'Discount Applied' column are: ['Yes' 'No']
#
# The unique values of the 'Promo Code Used' column are: ['Yes' 'No']
#
# The unique values of the 'Payment Method' column are: ['Venmo' 'Cash' 'Credit Card' 'PayPal' 'Bank Transfer' 'Debit Card']

# %% [markdown]
# ## OBSERVATION:
# Upon initial examination of the dataset, it is evident that we have a comprehensive and well-structured dataset with 3900 rows and 18 columns. The data is complete, with no missing values, which allows us to proceed confidently with our analysis.
#
# Let's delve into the columns and their significance in understanding our custome
#
# -  **Customer ID:** This column serves as a unique identifier for each customer, enabling us to differentiate between individuals.
# -  **Age:** The age column provides insights into the age demographics of our customers, helping us understand their preferences and behaviors.
# -  **Gender:** This column showcases the gender of the customers, enabling us to analyze buying patterns based on gender.
# -  **Item Purchased:** Here, we can identify the specific products that customers have bought, allowing us to gain an understanding of popular choices.
# -  **Category:** The category column categorizes the products into different groups such as clothing, footwear, and more, aiding us in analyzing trends within specific product categories.
# -  **Purchase Amount (USD):** This column reveals the amount customers spent on their purchases, providing insights into their spending habits.
# -  **Location:** The location column indicates the geographical location of customers, which can help identify regional trends and preferences.
# -  **Size:** This column denotes the size of the purchased products, assisting in understanding size preferences across different categories.
# -  **Color:** Here, we can determine the color preferences of customers, aiding in analyzing color trends and their impact on purchasing decisions.
# -  **Season:** The season column allows us to identify the season during which customers made their purchases, enabling us to explore seasonal shopping trends.
# -  **Review Rating:** This column showcases the ratings given by customers, providing valuable feedback on product satisfaction and quality.
# -  **Subscription Status:** This column indicates whether customers have opted for a subscription status, which can help us understand customer loyalty and engagement.
# -  **Shipping Type:** Here, we can identify the different shipping methods used to deliver products to customers, shedding light on preferred shipping options.
# -  **Discount Applied:** This column indicates whether a discount was applied to the purchased products, enabling us to analyze the impact of discounts on customer behavior.
# -  **Promo Code Used:** Here, we can identify whether customers utilized promo codes during their purchases, helping us evaluate the effectiveness of promotional campaigns.
# -  **Previous Purchases:** This column reveals the number of previous purchases made by customers, aiding in understanding customer loyalty and repeat business.
# -  **Payment Method:** The payment method column showcases the various methods used by customers to make their purchases, allowing us to analyze preferred payment options.
# -  **Frequency of Purchases:** This column provides insights into the frequency at which customers make purchases, helping us identify patterns and customer buying habits.
#
# ustomer buying habits.
# With this rich and diverse dataset, we are well-equipped to explore customer shopping trends, understand their preferences, and uncover valuable insights that can drive informed decision-making and enhance the overall customer experience. Let's embark on this exciting analysis journey!

# %% [markdown]
# ##  1. To know about overall distribution of customer ages in the dataset

# %% [markdown]
#  **purpose**:
#          - To analyze the frequency distribution of values in the Age column.
#          - Useful for identifying patterns, such as the most common age group in the dataset.
#     **Use Cases**:
#         - Understanding the demographic distribution of shoppers.
#         - Spotting outliers or unusual age entries.
#         - Preparing the data for visualization or further analysis

# %%
shop['Age'].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 50    83
# 54    83
# 27    83
# 62    83
# 32    82
# 19    81
# 58    81
# 42    80
# 43    79
# 28    79
# 31    79
# 37    77
# 46    76
# 29    76
# 68    75
# 59    75
# 63    75
# 56    74
# 36    74
# 55    73
# 52    73
# 64    73
# 35    72
# 51    72
# 65    72
# 40    72
# 45    72
# 47    71
# 66    71
# 30    71
# 23    71
# 38    70
# 53    70
# 18    69
# 21    69
# 26    69
# 34    68
# 48    68
# 24    68
# 39    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %% [markdown]
# ## Purpose of using shop['Age'].mean():
#          - To determine the average age of customers in the dataset.
#          - Useful for understanding the central tendency of the age distribution.

# %%
shop['Age'].mean()
# Out:
# 44.06846153846154

# %% [markdown]
# ## Purpose of using shop['Gender'].unique():
#          - To identify all the unique categories or values in the Gender column.
#          - Useful for understanding the data distribution or preparing data for analysis.

# %%
shop['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ### Code Explanation: Creating an Age Category Column
#
#  - The following code creates a new column in the DataFrame, `Age_category`, by categorizing the values in the `Age` column into specific age groups.

# %%
shop['Age_category'] = pd.cut(shop['Age'], bins= [0,15, 18 , 30 , 50 , 70] , labels= ['child' , 'teen' , 'Young Adults' ,'Middle-Aged Adults'
                                                                                             , 'old'] )

# %% [markdown]
# ### Code Explanation: Customizing Histogram Colors
#
# The following code creates a histogram to visualize the distribution of ages across different age categories with custom colors.

# %%
fig = px.histogram(shop , y = 'Age' , x = 'Age_category')
fig.show()

# %% [markdown]
# ## 2. To now  the average purchase amount vary across different product categories

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age_category'],
#       dtype='object')

# %%
shop['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %% [markdown]
# ### Code Explanation: Calculating the Average Purchase Amount by Category
#
# The following code calculates the average purchase amount for each product category by grouping the data by `Category` and then calculating the mean of `Purchase Amount (USD)`.

# %%
shop.groupby('Category')['Purchase Amount (USD)'].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# ## 3. To know which gender has the highest number of purchases

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age_category'],
#       dtype='object')

# %% [markdown]
# ### Code Explanation: Creating a Bar Plot with Custom Colors
#
# The following code creates a bar plot to visualize the `Purchase Amount (USD)` by `Gender`, with custom colors for each gender.

# %%
sns.barplot(shop , x = 'Gender' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# ## 4. To know the most commonly purchased items in each category

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age_category'],
#       dtype='object')

# %% [markdown]
# ### Code Explanation: Counting the Number of Items Purchased per Category
#
# The following code calculates the number of times each item was purchased within each product category.

# %%
shop.groupby('Category')['Item Purchased'].value_counts()
# Out:
# Category     Item Purchased
# Accessories  Jewelry           171
#              Belt              161
#              Sunglasses        161
#              Scarf             157
#              Hat               154
#              Handbag           153
#              Backpack          143
#              Gloves            140
# Clothing     Blouse            171
#              Pants             171
#              Shirt             169
#              Dress             166
#              Sweater           164
#              Socks             159
#              Skirt             158
#              Shorts            157
#              Hoodie            151
#              T-shirt           147
#              Jeans             124
# Footwear     Sandals           160
#              Shoes             150
#              Sneakers          145
#              Boots             144
# Outerwear    Jacket            163
#              Coat              161
# Name: count, dtype: int64

# %% [markdown]
# ### Code Explanation: Creating a Histogram for Item Purchases by Category
#
# The following code creates a histogram to visualize the distribution of `Item Purchased` based on different product `Category`,
# with different colors for each category.

# %%
fig = px.histogram(shop , x = 'Item Purchased' , color = 'Category')
fig.show()

# %% [markdown]
# ## 5 . To know if there are any specific seasons or months where customer spending is significantly higher

# %% [markdown]
# ### Code Explanation: Checking Unique Values in the 'Season' Column
#
# The following code retrieves all the unique values present in the `Season` column of the dataset.

# %%
shop['Season'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Fall'], dtype=object)

# %% [markdown]
# ### Code Explanation: Counting Total Occurrences of 'Summer', 'Winter', 'Spring' and  'Fall'  Seasons Entries
#
# The following codes counts the total number of rows in the dataset where the `Season` is 'Summer', 'Winter', 'Spring'
# and 'Fall' considering all columns.

# %%
shop[shop['Season'] == 'Summer'].value_counts().sum()
# Out:
# 955

# %%
shop[shop['Season'] == 'Winter'].value_counts().sum()
# Out:
# 971

# %%
shop[shop['Season'] == 'Spring'].value_counts().sum()
# Out:
# 999

# %%
shop[shop['Season'] == 'Fall'].value_counts().sum()
# Out:
# 975

# %% [markdown]
# ### Code Explanation: Creating a Colored Histogram for 'Season' with Y-axis Range
#
# The following code creates a histogram to visualize the distribution of data across different seasons, with each season represented by a unique color. The y-axis is restricted between 200 and 1500.

# %%
fig = px.histogram(shop , x = 'Season' , range_y= [200 , 1500] )

fig.show()

# %% [markdown]
# ## 6. To know  the average rating given by customers for each product category

# %%
shop_groupby = shop.groupby('Category')['Review Rating'].mean().reset_index()

# %%
fig = px.bar(shop_groupby ,x= 'Category' , y = 'Review Rating' )
fig.show()

# %% [markdown]
# ## 7  To know  notable differences in purchase behavior between subscribed and non-subscribed customers

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age_category'],
#       dtype='object')

# %% [markdown]
# ### Code Explanation: Retrieving Unique Values in the 'Subscription Status' Column
# The following code retrieves all the unique values present in the `Subscription Status` column of the dataset.

# %%
shop['Subscription Status'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# # Bar Plot: Subscription Status vs. Purchase Amount (USD)
#
# This section demonstrates how to use `seaborn.barplot` to visualize the relationship between **Subscription Status** and **Purchase Amount (USD)**. The bar plot shows the average purchase amount for each subscription status category.

# %%
sns.barplot(shop  , x = 'Subscription Status' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Subscription Status', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# ### Code Explanation: Calculating the Total 'Purchase Amount (USD)'
#
# The following code calculates the total sum of the `Purchase Amount (USD)` column in the `shop` DataFrame.

# %%
shop['Purchase Amount (USD)'].sum()
# Out:
# 233081

# %% [markdown]
# ### Code Explanation: Calculating the Mean Purchase Amount by 'Subscription Status'
#
# The following code calculates the average (mean) `Purchase Amount (USD)` for each unique value in the `Subscription Status` column.

# %%
shop.groupby('Subscription Status')['Purchase Amount (USD)'].mean()
# Out:
# Subscription Status
# No     59.865121
# Yes    59.491928
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# ## 8 To know payment method is the most popular among customers

# %% [markdown]
# ### Code Explanation: Calculating the Mean Purchase Amount by 'Payment Method' and Sorting
#
# The following code calculates the average (`mean`) `Purchase Amount (USD)` for each payment method and sorts the results in descending order.

# %%
shop.groupby('Payment Method')['Purchase Amount (USD)'].mean().sort_values(ascending= False)
# Out:
# Payment Method
# Debit Card       60.915094
# Credit Card      60.074516
# Bank Transfer    59.712418
# Cash             59.704478
# PayPal           59.245199
# Venmo            58.949527
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# ### Code Explanation: Grouping Data by 'Payment Method' and Resetting Index
#
# The following code calculates the average (`mean`) `Purchase Amount (USD)` for each payment method and resets the index of the resulting DataFrame.

# %%
shop_groupby = shop.groupby('Payment Method')['Purchase Amount (USD)'].mean().reset_index()

# %% [markdown]
# ### Code Explanation: Creating a Bar Plot with Custom Colors for 'Payment Method'
#
# The following code creates a bar plot to visualize the average `Purchase Amount (USD)` for each payment method. The bars are colored based on the `Payment Method`, with each method receiving a distinct color.

# %%
fig = px.bar(shop_groupby , x = 'Payment Method' , y = 'Purchase Amount (USD)')
fig.show()

# %% [markdown]
# ### Code Explanation: Customizing Colors in a Seaborn Bar Plot
#
# The following code creates a bar plot to visualize the average `Purchase Amount (USD)` for each `Payment Method`, with each payment method represented in a  color.

# %%
sns.barplot(shop ,x='Payment Method' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Payment Method', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# ## 7. To know customers who use promo codes tend to spend more than those who don't

# %% [markdown]
# ### Code Explanation: Grouping Data by 'Promo Code Used' and Calculating the Total Purchase Amount
#
# The following code calculates the total (`sum`) `Purchase Amount (USD)` for each `Promo Code Used` and resets the index of the resulting DataFrame.

# %%
shop_groupby  = shop.groupby('Promo Code Used')['Purchase Amount (USD)'].sum().reset_index()

# %% [markdown]
# ### Code Explanation: Creating a Sunburst Chart to Visualize Purchase Amount by 'Gender' and 'Promo Code Used'
#
# The following code creates a sunburst chart to visualize the relationship between `Gender` and `Promo Code Used` with respect to `Purchase Amount (USD)`.

# %%
fig = px.sunburst(shop , path=['Gender' , 'Promo Code Used'] , values='Purchase Amount (USD)')
fig.show()

# %% [markdown]
# ### Code Explanation: Modifying Colors in a Bar Chart to Visualize Purchase Amount by Promo Code Used
#
# The following code creates a bar chart to visualize the total `Purchase Amount (USD)` for each `Promo Code Used` category, with distinct colors for each category.

# %%
fig  =  px.bar(shop_groupby , x= 'Promo Code Used' , y = 'Purchase Amount (USD)')
fig.show()

# %% [markdown]
# ## 10. To know the frequencies of purchases vary across different age groups

# %% [markdown]
# ### Code Explanation: Selecting Specific Columns from the DataFrame
#
# The following code selects the `Age` and `Age_category` columns from the `shop` DataFrame and displays them.

# %%
shop[['Age' , 'Age_category']]
# Out:
#       Age        Age_category
# 0      55                 old
# 1      19        Young Adults
# 2      50  Middle-Aged Adults
# 3      21        Young Adults
# 4      45  Middle-Aged Adults
# ...   ...                 ...
# 3895   40  Middle-Aged Adults
# 3896   52                 old
# 3897   46  Middle-Aged Adults
# 3898   44  Middle-Aged Adults
# 3899   52                 old
#
# [3900 rows x 2 columns]

# %% [markdown]
# ### Code Explanation: Displaying Unique Values in the 'Age_category' Column
#
# The following code retrieves the unique values from the `Age_category` column in the `shop` DataFrame.

# %%
shop['Age_category'].unique()
# Out:
# ['old', 'Young Adults', 'Middle-Aged Adults', 'teen']
# Categories (5, object): ['child' < 'teen' < 'Young Adults' < 'Middle-Aged Adults' < 'old']

# %% [markdown]
# ### Code Explanation: Grouping Data by 'Frequency of Purchases' and Summing 'Age'
#
# The following code groups the `shop` DataFrame by the `Frequency of Purchases` column and then calculates the sum of the `Age` values for each group.

# %%
shop_group = shop.groupby('Frequency of Purchases')['Age'].sum()

# %% [markdown]
# ### Code Explanation: Creating a Sunburst Chart to Visualize Age Distribution by Purchase Frequency and Age Category
#
# The following code creates a sunburst chart using Plotly to visualize the distribution of `Age` grouped by `Frequency of Purchases` and `Age_category`.
#
# # Resolving the Sunburst Chart Issue with Plotly
#
# The error occurs because the column `Age_category` does not exist in the `shop` DataFrame. Below are the steps to fix this issue by either using existing columns or creating the required `Age_category` column.
#
# ---
#
# ## Existing Columns in Your DataFrame
# From the error message, the columns available in your `shop` DataFrame are:

# %%
import plotly.express as px

# Using existing columns in your DataFrame
fig = px.sunburst(
    shop,
    path=['Frequency of Purchases', 'Category'],  # Replace 'Age_category' with an actual column name
    values='Age',  # Use 'Age' as the size of segments
    title="Sunburst Chart with Existing Columns"
)

fig.show()

# %% [markdown]
# ## 11. To know  any correlations between the size of the product and the purchase amount

# %% [markdown]
# ### Code Explanation: Displaying Column Names in the DataFrame
#
# The following code retrieves and displays the column names of the `shop` DataFrame.

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age_category'],
#       dtype='object')

# %% [markdown]
# ### Code Explanation: Grouping Data by 'Size' and Summing 'Purchase Amount (USD)'
#
# The following code groups the `shop` DataFrame by the `Size` column and calculates the sum of `Purchase Amount (USD)` for each group.

# %%
shop_group = shop.groupby('Size')['Purchase Amount (USD)'].sum().reset_index()

# %% [markdown]
# ### Code Explanation: Creating a Bar Chart with Custom Colors for 'Size' and 'Purchase Amount (USD)'
#
# The following code creates a bar chart to visualize the total `Purchase Amount (USD)` for each `Size` category, with custom colors for each `Size` group.

# %%
fig  = px.bar(shop_group , x = 'Size' , y ='Purchase Amount (USD)'  )
fig.show()

# %% [markdown]
# ## 12. To know  which shipping type is preferred by customers for different product categories

# %% [markdown]
# ### Code Explanation: Grouping Data by 'Category' and Counting 'Shipping Type' Values
#
# The following code groups the `shop` DataFrame by the `Category` column and counts the occurrences of each `Shipping Type` within each category, sorting the result in descending order.

# %%
shop.groupby('Category')['Shipping Type'].value_counts().sort_values(ascending= False)
# Out:
# Category     Shipping Type
# Clothing     Standard          297
#              Free Shipping     294
#              Next Day Air      293
#              Express           290
#              Store Pickup      282
#              2-Day Shipping    281
# Accessories  Store Pickup      217
#              Next Day Air      211
#              Standard          208
#              2-Day Shipping    206
#              Express           203
#              Free Shipping     195
# Footwear     Free Shipping     122
#              Standard          100
#              Store Pickup       98
#              Express            96
#              Next Day Air       93
#              2-Day Shipping     90
# Outerwear    Free Shipping      64
#              Express            57
#              Store Pickup       53
#              Next Day Air       51
#              2-Day Shipping     50
#              Standard           49
# Name: count, dtype: int64

# %% [markdown]
# ### Code Explanation: Mapping 'Shipping Type' to Numeric Values
#
# The following code creates a new column, `Shipping_Category`, in the `shop` DataFrame, which maps the different shipping types to corresponding numeric values.

# %%
shop['Shipping_Category'] =shop['Shipping Type'].map({'Express': 0, 'Free Shipping': 1, 'Next Day Air': 2,
                                                       'Standard': 3, '2-Day Shipping': 4, 'Store Pickup': 5})

# %% [markdown]
# ### Code Explanation: Extracting Unique Values from 'Category' Column
#
# The following code retrieves the unique values from the `Category` column in the `shop` DataFrame.

# %%
shop['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %% [markdown]
# ### Code Explanation: Mapping 'Category' to Numeric Values
#
# The following code creates a new column, `Category_num`, in the `shop` DataFrame, which maps the different categories of products to corresponding numeric values.

# %%
shop['Category_num'] =shop['Category'].map({'Clothing':1, 'Footwear':2, 'Outerwear':3, 'Accessories':4})

# %% [markdown]
# ## 13. To know the presences of a discount affect the purchase decision of customers

# %% [markdown]
# ### Code Explanation: Listing the Columns of the DataFrame
#
# The following code lists all the column names present in the `shop` DataFrame.

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age_category',
#        'Shipping_Category', 'Category_num'],
#       dtype='object')

# %%
shop_group = shop.groupby('Discount Applied')['Purchase Amount (USD)'].sum().reset_index()

# %% [markdown]
# ### Code Explanation: Plotting Histogram with Custom Colors
#
# This code generates a histogram of the `Purchase Amount (USD)` by the `Discount Applied` category, with custom colors for each discount type.

# %%
px.histogram(shop_group , x = 'Discount Applied' , y = 'Purchase Amount (USD)')

# %% [markdown]
# ### Code Explanation: Creating a Sunburst Plot with Custom Colors
#
# This code generates a sunburst plot that visualizes the distribution of the `Purchase Amount (USD)` across different categories of `Gender` and `Discount Applied`. The plot uses different colors for each gender category.

# %%
fig = px.sunburst(shop , path = ['Gender' , 'Discount Applied'], values='Purchase Amount (USD)' , color= 'Gender')

fig.show()

# %% [markdown]
# ## 14. To know if  there are any specific colors that are more popular among customers

# %% [markdown]
# ### Code Explanation: Modifying Colors in a Histogram
#
# This code generates a histogram of the `Color` column, and each color category is displayed with a custom color using `color_discrete_map`.

# %%
px.histogram(shop , x = 'Color')

# %% [markdown]
# ### Code Explanation: Getting the Top 5 Most Frequent Colors
#
# This code retrieves the top 5 most frequently occurring colors in the `Color` column of the `shop` DataFrame.
# The `value_counts()` function counts the occurrences of each unique value in the column, and `nlargest(5)` returns the top 5 most frequent values.

# %%
shop['Color'].value_counts().nlargest(5)
# Out:
# Color
# Olive     177
# Yellow    174
# Silver    173
# Teal      172
# Green     169
# Name: count, dtype: int64

# %% [markdown]
# ## 15. To know the average number of previous purchases made by customers

# %% [markdown]
# # Calculating the Mean of 'Previous Purchases'
#
# This section explains how to calculate the mean of the **`Previous Purchases`** column from a pandas DataFrame named `shop`.

# %%
shop['Previous Purchases'].mean()
# Out:
# 25.35153846153846

# %% [markdown]
# ## 16. To know if there are  any noticeable differences in purchase behavior between different locations

# %% [markdown]
# ### Code Explanation: Calculating Average Purchase Amount by Location
#
# This code calculates the average purchase amount (`Purchase Amount (USD)`) for each unique location in the `Location` column of the `shop` DataFrame, and then sorts the results in descending order to show the locations with the highest average purchase amounts.

# %%
shop.groupby('Location')['Purchase Amount (USD)'].mean().sort_values(ascending = False)
# Out:
# Location
# Alaska            67.597222
# Pennsylvania      66.567568
# Arizona           66.553846
# West Virginia     63.876543
# Nevada            63.379310
# Washington        63.328767
# North Dakota      62.891566
# Virginia          62.883117
# Utah              62.577465
# Michigan          62.095890
# Tennessee         61.974026
# New Mexico        61.901235
# Rhode Island      61.444444
# Texas             61.194805
# Arkansas          61.113924
# Illinois          61.054348
# Mississippi       61.037500
# Massachusetts     60.888889
# Iowa              60.884058
# North Carolina    60.794872
# Wyoming           60.690141
# South Dakota      60.514286
# New York          60.425287
# Ohio              60.376623
# Montana           60.250000
# Idaho             60.075269
# Nebraska          59.448276
# New Hampshire     59.422535
# Alabama           59.112360
# California        59.000000
# Indiana           58.924051
# Georgia           58.797468
# ...

# %% [markdown]
# ### Code Explanation: Calculating and Resetting Grouped Data by Location
#
# This code calculates the average (`mean()`) of the `Purchase Amount (USD)` for each unique location in the `Location` column of the `shop` DataFrame and resets the index to return a DataFrame.

# %%
shop_group = shop.groupby('Location')['Purchase Amount (USD)'].mean().reset_index()

# %% [markdown]
# ### Code Explanation: Modifying Colors in a Bar Chart by Location
#
# This code creates a bar chart that displays the average purchase amount for each location, with custom colors applied to each location.

# %%
fig = px.bar(shop_group, x = 'Location' , y = 'Purchase Amount (USD)')
fig.show()

# %% [markdown]
# ## 17. To know there is  a relationship between customer age and the category of products they purchase

# %% [markdown]
# ### Code Explanation: Calculating the Average Age by Category
#
# This code calculates the average age (`Age`) for each unique category in the `Category` column of the `shop` DataFrame and resets the index to return a new DataFrame.

# %%
shop_group = shop.groupby('Category')['Age'].mean().reset_index()

# %% [markdown]
# # Bar Chart: Age Distribution by Category
#
# This section demonstrates how to create an interactive bar chart using Plotly Express (`px.bar`). The chart visualizes the relationship between **Category** (x-axis) and **Age** (y-axis) from the DataFrame `shop_group`.

# %%
fig = px.bar(shop_group ,y = 'Age' , x= 'Category')
fig.show()

# %% [markdown]
# ##  18 To know the average purchase amount differ between male and female customers

# %%
shop_group = shop.groupby('Gender')['Purchase Amount (USD)'].sum().reset_index()

# %% [markdown]
# ### Code Explanation: Modifying Colors in a Bar Chart by Gender
#
# This code generates a bar chart that displays the total `Purchase Amount (USD)` by `Gender` and customizes the colors of the bars based on gender.

# %%
fig = px.bar(shop_group , x = 'Gender' , y = 'Purchase Amount (USD)')
fig.show()

# %% [markdown]
# ### Code Explanation: Creating a Sunburst Chart by Gender and Age Category
#
# This code generates a sunburst chart to visualize the distribution of `Purchase Amount (USD)` by `Gender` and `Age_category`.

# %%
px.sunburst(data_frame= shop , path = ['Gender' ,'Age_category'] , values='Purchase Amount (USD)')
